# %%
print(10+10)
# Out:
# 20

# %%
print(20-10)
# Out:
# 10

# %%
print(4*6)
# Out:
# 24

# %%
print(10/2)
# Out:
# 5.0

# %%
print(11/10)
# Out:
# 1.1

# %%
print(2**2)
# Out:
# 4

# %%
age = 19
print(age>18 and age<30)
# Out:
# True

# %%
age = 25
print(age>18 or age<20)
# Out:
# True

# %%
age = 20
print(not(age>18))
# Out:
# False

# %%
print(10>5)
# Out:
# True

# %%
print(20<10)
# Out:
# False

# %%
print(10==10)
# Out:
# True

# %%
print(20>=10)
# Out:
# True

# %%
print(20<=10)
# Out:
# False

# %%
print(10!=10)
# Out:
# False

# %%
a=10
a+=5
print(a)
# Out:
# 15

# %%
a=10
a-=5
print(a)
a*=5
print(a)
a/=2
print(a)
# Out:
# 5
# 25
# 12.5

# %%
a=25
print(a)
print(type(a))
# Out:
# 25
# <class 'int'>

# %%
is_student = True
print(type(is_student))
# Out:
# <class 'bool'>

# %%
b = 2.4
print(type(b))
c="dkte"
print(type(c))
# Out:
# <class 'float'>
# <class 'str'>

# %%
a = 10.9
print(type(a))
print(int(a))
# Out:
# <class 'float'>
# 10

# %%
print("hello")
input("Enter your name")
# Out:
# hello
# Enter your namesamruddhi
# 'samruddhi'

# %%
print("enter your name")
input()
# Out:
# enter your name
# aryan
# 'aryan'

# %%
name = input("Enter name")
print("hello",name)
# Out:
# Enter namevaishni
# hello vaishni

# %%
name = input("enter name\n")
age = input("enter age\n")
print("My name is",name,"My age is",age)
# Out:
# enter name
# samu
# enter age
# 19
# My name is samu My age is 19

# %%
a=input("Enter num 1\n")
b=input("Enetr num 2\n")
print(a+b)
# Out:
# Enter num 1
# 12
# Enetr num 2
# 23
# 1223

# %%
a=int(input("Enter num 1\n"))
b=int(input("Enetr num 2\n"))
print(a+b)
# Out:
# Enter num 1
# 12
# Enetr num 2
# 12
# 24
