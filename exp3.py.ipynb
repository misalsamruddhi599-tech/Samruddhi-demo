# %%
str1='dkte'
str2 = "dkte"
print(type(str1))
print(type(str2))
str3='''dkte'''
print(type(str3))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
str1='dkte'
str2='college'
print(str1+str2)
print(str1+' '+str2)
# Out:
# dktecollege
# dkte college

# %%
str1="HELLO"
print(str1[1])
print(str1[2])
print(str1[0])
print(str1[6])
# Out:
# E
# L
# H
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-f0fbbed5c5b7> in <module>
#       3 print(str1[2])
#       4 print(str1[0])
# ----> 5 print(str1[6])
#
# IndexError: string index out of range

# %%
str1='dkte'
print(str1[1:3])
print(str1[0:3])
print(str1[ :2])
print(str1[1: ])
print(str1[ : ])
# Out:
# kt
# dkt
# dk
# kte
# dkte

# %%
str1='dkte'
print(str1[-1:-4])

# %%
str1='dkte'
print(len(str1))
str2="samruddhi misal"
print(len(str2))
# Out:
# 4
# 15

# %%
str1="samruddhi jotiram misal"
print(str1[10:18])
# Out:
# jotiram

# %%
str(input("enter your name "))
print(str1[10:18])
# Out:
# enter your name samruddhi jotiramj misal
# jotiram

# %%
str1='Dkte'
print(str1.startswith('D'))
# Out:
# True

# %%
str1='Dkte'
print(str1.startswith('d'))
# Out:
# False

# %%
str1='Dkte'
print(str1.endswith('e'))
# Out:
# True

# %%
str1='Dkte'
print(str1.istitle())
print(str1.isupper())
print(str1.islower())
# Out:
# True
# False
# False

# %%
str2="DKTE"
print(str2.isupper())
# Out:
# True

# %%
str1='dkte'
print(str1.upper())
# Out:
# DKTE

# %%
str1='DKTE'
print(str1.lower())
# Out:
# dkte

# %%
str1='1020'
print(str1.isdecimal())
# Out:
# True

# %%
str1='DKTE'
print(str1.isalpha())
# Out:
# True

# %%
str1="Ichalkaranji"
print(str1.find('a'))
print(str1.count('a'))
print(str1.replace('a','k'))
# Out:
# 3
# 3
# Ichklkkrknji
